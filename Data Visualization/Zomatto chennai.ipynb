# %% [markdown]
# # 1. Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# # 2. Importing the dataset

# %%
raw_df = pd.read_csv('ChennaiZomato.csv')

# %%
raw_df
# Out:
#           Name of Restaurant    Location           Cuisine  \
# 0      Yaa Mohaideen Briyani  Pallavaram       ['Biryani']
# 1         Sukkubhai Biriyani     Alandur        ['Biryani'
# 2         Sukkubhai Biriyani     Alandur   ' North Indian'
# 3         Sukkubhai Biriyani     Alandur        ' Mughlai'
# 4         Sukkubhai Biriyani     Alandur       ' Desserts'
# ...                      ...         ...               ...
# 12306      Engineers Kitchen    Ambattur   ['North Indian'
# 12307      Engineers Kitchen    Ambattur        ' Chinese'
# 12308      Engineers Kitchen    Ambattur        ' Andhra']
# 12309        That Juice Shop  Karapakkam         ['Juices'
# 12310        That Juice Shop  Karapakkam     ' Beverages']
#
#                                               Top Dishes  Price for 2  \
# 0      ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...          500
# 1      ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# ...

# %%
raw_df.head()
# Out:
#       Name of Restaurant    Location           Cuisine  \
# 0  Yaa Mohaideen Briyani  Pallavaram       ['Biryani']
# 1     Sukkubhai Biriyani     Alandur        ['Biryani'
# 2     Sukkubhai Biriyani     Alandur   ' North Indian'
# 3     Sukkubhai Biriyani     Alandur        ' Mughlai'
# 4     Sukkubhai Biriyani     Alandur       ' Desserts'
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...          500
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 2  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 3  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 4  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
#
#    Dining Rating  Dining Rating Count  Delivery Rating  Delivery Rating Count  \
# 0            4.3                 1500              4.3                   9306
# ...

# %%
print(raw_df.columns)
# Out:
# Index(['Name of Restaurant', 'Location', 'Cuisine', 'Top Dishes',
#        'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='object')

# %% [markdown]
# # 3. Getting Basic Information about the Dataset

# %%
raw_df.shape
# Out:
# (12311, 10)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12311 entries, 0 to 12310
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     12311 non-null  object
#  1   Location               12311 non-null  object
#  2   Cuisine                12311 non-null  object
#  3   Top Dishes             12311 non-null  object
#  4   Price for 2            12311 non-null  int64
#  5   Dining Rating          12311 non-null  float64
#  6   Dining Rating Count    12311 non-null  int64
#  7   Delivery Rating        12311 non-null  float64
#  8   Delivery Rating Count  12311 non-null  int64
#  9   Features               12311 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 961.9+ KB

# %%
raw_df.describe()
# Out:
#         Price for 2  Dining Rating  Dining Rating Count  Delivery Rating  \
# count  12311.000000   12311.000000         12311.000000     12311.000000
# mean     480.027618       3.486500           204.706685         3.841126
# std      259.805024       0.517718           398.220049         0.311581
# min      100.000000       1.700000             4.000000         2.100000
# 25%      300.000000       3.200000            22.000000         3.700000
# 50%      400.000000       3.500000            69.000000         3.900000
# 75%      600.000000       3.800000           218.000000         4.000000
# max     3000.000000       4.900000          5407.000000         4.700000
#
#        Delivery Rating Count
# count           12311.000000
# mean             1939.894810
# std              4033.121024
# min                11.000000
# 25%               141.000000
# 50%               500.000000
# 75%              1831.000000
# max             59900.000000

# %%
raw_df.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %% [markdown]
# # 4. cleaning the dataset

# %% [markdown]
# # c. Converting the DataTypes of numerical columns to numeric dataype

# %%
# Changing Data Type of the numerical columns
raw_df['Price for 2'] = raw_df['Price for 2'].astype('int64')
raw_df['Dining Rating'] = raw_df['Dining Rating'].astype('float64')
raw_df['Dining Rating Count'] = raw_df['Dining Rating Count'].astype('int64')
raw_df['Delivery Rating'] = raw_df['Delivery Rating'].astype('float64')
raw_df['Delivery Rating Count'] = raw_df['Delivery Rating Count'].astype('int64')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12311 entries, 0 to 12310
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     12311 non-null  object
#  1   Location               12311 non-null  object
#  2   Cuisine                12311 non-null  object
#  3   Top Dishes             12311 non-null  object
#  4   Price for 2            12311 non-null  int64
#  5   Dining Rating          12311 non-null  float64
#  6   Dining Rating Count    12311 non-null  int64
#  7   Delivery Rating        12311 non-null  float64
#  8   Delivery Rating Count  12311 non-null  int64
#  9   Features               12311 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 961.9+ KB

# %% [markdown]
# # convert the categorical to numerical column

# %%
zomato_df = pd.read_csv('ChennaiZomato.csv')
from sklearn.preprocessing import LabelEncoder
# Create a LabelEncoder instance
label_encoder = LabelEncoder()
# Apply Label Encoding to the columns: 'Cuisine', 'Location', and 'Features'
zomato_df['Cuisine_numerical'] = label_encoder.fit_transform(zomato_df['Cuisine'])
zomato_df['Location_numerical'] = label_encoder.fit_transform(zomato_df['Location'])
zomato_df['Features_numerical'] = label_encoder.fit_transform(zomato_df['Features'])
# Check the dataframe with the new numerical columns
print(zomato_df[['Cuisine', 'Cuisine_numerical', 'Location', 'Location_numerical', 'Features', 'Features_numerical']].head())
# Out:
#             Cuisine  Cuisine_numerical    Location  Location_numerical  \
# 0       ['Biryani']                141  Pallavaram                 102
# 1        ['Biryani'                140     Alandur                   6
# 2   ' North Indian'                 88     Alandur                   6
# 3        ' Mughlai'                 85     Alandur                   6
# 4       ' Desserts'                 33     Alandur                   6
#
#                                             Features  Features_numerical
# 0                ['Home Delivery', 'Indoor Seating']                 445
# 1  ['Home Delivery', 'Free Parking', 'Table booki...                 320
# 2  ['Home Delivery', 'Free Parking', 'Table booki...                 320
# 3  ['Home Delivery', 'Free Parking', 'Table booki...                 320
# 4  ['Home Delivery', 'Free Parking', 'Table booki...                 320

# %% [markdown]
# # working with cuisine column

# %%
raw_df['Cuisine'].value_counts()
# Out:
# Cuisine
#  ' Chinese'         852
#  ' Beverages']      673
#  ' North Indian'    593
# ['North Indian'     588
#  ' Fast Food']      571
#                    ...
#  ' Korean']           1
# ['Burger']            1
# ['Continental']       1
#  ' Finger Food']      1
#  ' Goan']             1
# Name: count, Length: 219, dtype: int64

# %%
# If 'Cuisine' is a list of categories, split them and label encode each
zomato_df['Cuisine'] = zomato_df['Cuisine'].apply(lambda x: x.strip("[]").replace("'", "").split(',') if isinstance(x, str) else x)
# Example: Now we use LabelEncoder on each element of a list in the 'Cuisine' column
zomato_df['Cuisine_numerical'] = zomato_df['Cuisine'].apply(lambda x: [label_encoder.fit_transform([item])[0] for item in x])

# %% [markdown]
# # working with loacation column

# %%
raw_df['Location'].value_counts()
# Out:
# Location
# Anna Nagar                             738
# Porur                                  407
# Velachery                              372
# T.Nagar                                359
# Ambattur                               333
#                                       ...
# OMR, Old Mahabalipuram Road (OMR)        2
# Kora Food Street, Anna Nagar             1
# TNHB Complex, Adyar                      1
# Ponnis Grand Inn Hotel, Thiruvallur      1
# Eat And Pack, Ambattur                   1
# Name: count, Length: 159, dtype: int64

# %%
zomato_df['Location'] = zomato_df['Location'].apply(lambda x: x.strip("[]").replace("'", "").split(',') if isinstance(x, str) else x)
# Example: Now we use LabelEncoder on each element of a list in the 'Location' column
zomato_df['Location_numerical'] = zomato_df['Location'].apply(lambda x: [label_encoder.fit_transform([item])[0] for item in x])

# %% [markdown]
# # working with Top Dishes column

# %%
raw_df['Top Dishes'].value_counts()
# Out:
# Top Dishes
# Invalid                                                                                                                         6963
# ['Biryani']                                                                                                                       83
# ['Chicken Biryani']                                                                                                               33
# ['Coffee']                                                                                                                        32
# ['Sandwich']                                                                                                                      30
#                                                                                                                                 ...
# ['Cheese Balls', ' Chicken Curry', ' Kozhi Idli', ' Chicken Soup', ' Pepper Kolambu', ' Chicken Thokku', ' Caramel Custard']       1
# ...

# %% [markdown]
# # working with price for2

# %%
raw_df['Price for 2'].value_counts()
# Out:
# Price for 2
# 500     1609
# 400     1569
# 300     1548
# 350     1009
# 200      989
# 600      981
# 250      791
# 450      676
# 800      517
# 700      494
# 550      472
# 150      295
# 1000     253
# 900      240
# 650      220
# 750      156
# 850      106
# 1200      77
# 1500      71
# 100       51
# 1600      43
# 1400      31
# 1300      30
# 1100      30
# 1800      22
# 2000       9
# 3000       5
# 1700       4
# 2700       4
# 2400       4
# 330        3
# 160        1
# 120        1
# Name: count, dtype: int64

# %% [markdown]
# # working with Dining Rating column

# %%
raw_df['Dining Rating'].value_counts()
# Out:
# Dining Rating
# 3.7    1039
# 3.6    1021
# 3.5     945
# 3.8     935
# 3.9     883
# 3.4     865
# 3.3     781
# 3.2     670
# 4.0     668
# 3.1     663
# 4.1     553
# 3.0     532
# 2.9     457
# 4.2     361
# 2.8     328
# 4.3     295
# 2.0     260
# 2.7     226
# 2.6     172
# 4.4     150
# 2.5     135
# 2.4      95
# 4.5      85
# 2.3      59
# 4.6      33
# 2.2      27
# 4.7      22
# 2.1      22
# 4.9      20
# 4.8       7
# 1.7       2
# Name: count, dtype: int64

# %% [markdown]
# # working with Dining Rating Count Column

# %%
raw_df['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# 6      250
# 4      242
# 5      222
# 8      206
# 9      201
#       ...
# 904      1
# 152      1
# 284      1
# 848      1
# 961      1
# Name: count, Length: 746, dtype: int64

# %% [markdown]
# # working with Delivery Rating column

# %%
raw_df['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 3.9    2568
# 3.8    1567
# 4.0    1253
# 3.7    1202
# 4.1     995
# 3.6     916
# 4.2     885
# 4.3     639
# 3.5     582
# 3.4     491
# 3.3     333
# 4.4     243
# 3.2     151
# 3.1     125
# 4.5     107
# 3.0      94
# 2.9      56
# 4.6      34
# 2.8      20
# 2.7      14
# 2.6      14
# 2.4       7
# 2.2       5
# 2.1       5
# 4.7       4
# 2.3       1
# Name: count, dtype: int64

# %% [markdown]
# # working with Delivery Rating Count Column

# %%
raw_df['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# 51      57
# 44      53
# 47      52
# 48      52
# 38      50
#         ..
# 556      1
# 1474     1
# 2744     1
# 7591     1
# 1617     1
# Name: count, Length: 2024, dtype: int64

# %% [markdown]
# # working with Features Column

# %%
raw_df['Features'].value_counts()
# Out:
# Features
# ['Home Delivery', 'Indoor Seating']                                                                                                                     3671
# ['Breakfast', 'Home Delivery', 'Indoor Seating']                                                                                                         686
# ['Home Delivery', 'Free Parking', 'Indoor Seating']                                                                                                      588
# ['Home Delivery', 'Indoor Seating', 'Desserts and Bakes']                                                                                                502
# ['Breakfast', 'Home Delivery', 'Vegetarian Only', 'Indoor Seating']                                                                                      379
#                                                                                                                                                         ...
# ...

# %%
zomato_df['Features'] = zomato_df['Features'].apply(lambda x: x.strip("[]").replace("'", "").split(',') if isinstance(x, str) else x)
# Example: Now we use LabelEncoder on each element of a list in the 'Features' column
zomato_df['Features_numerical'] = zomato_df['Features'].apply(lambda x: [label_encoder.fit_transform([item])[0] for item in x])

# %% [markdown]
#  # Removing Duplicate records

# %%
# Finding all the duplicate rows
raw_df[raw_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
# Dropping all the duplicate rows
raw_df = raw_df.drop_duplicates()

# %% [markdown]
# # 4. Copying the cleaned data into a new DataFrame

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant    Location           Cuisine  \
# 0  Yaa Mohaideen Briyani  Pallavaram       ['Biryani']
# 1     Sukkubhai Biriyani     Alandur        ['Biryani'
# 2     Sukkubhai Biriyani     Alandur   ' North Indian'
# 3     Sukkubhai Biriyani     Alandur        ' Mughlai'
# 4     Sukkubhai Biriyani     Alandur       ' Desserts'
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...          500
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 2  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 3  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 4  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
#
#    Dining Rating  Dining Rating Count  Delivery Rating  Delivery Rating Count  \
# 0            4.3                 1500              4.3                   9306
# ...

# %% [markdown]
#  # 5. Performing Exploratory Data Analysis
# Q1) How many restaurants are in chennai for each type of cuisine?

# %%
fig = px.histogram(zomato_df, x='Cuisine', color='Dining Rating',
title= 'No. of Restaurants by Cuisine',
labels={'CUSINE TYPE':'Cuisine Type'})
fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in chennai?

# %%
rating_type_df = zomato_df['Dining Rating'].value_counts().reset_index()

# %%
rating_type_df.rename(columns={'index':'Dining Rating', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
rating_type_df
# Out:
#     Dining Rating  count
# 0             3.7   1039
# 1             3.6   1021
# 2             3.5    945
# 3             3.8    935
# 4             3.9    883
# 5             3.4    865
# 6             3.3    781
# 7             3.2    670
# 8             4.0    668
# 9             3.1    663
# 10            4.1    553
# 11            3.0    532
# 12            2.9    457
# 13            4.2    361
# 14            2.8    328
# 15            4.3    295
# 16            2.0    260
# 17            2.7    226
# 18            2.6    172
# 19            4.4    150
# 20            2.5    135
# 21            2.4     95
# 22            4.5     85
# 23            2.3     59
# 24            4.6     33
# 25            2.2     27
# 26            4.7     22
# 27            2.1     22
# 28            4.9     20
# 29            4.8      7
# 30            1.7      2

# %%
print(rating_type_df.head())
# Out:
#    Dining Rating  count
# 0            3.7   1039
# 1            3.6   1021
# 2            3.5    945
# 3            3.8    935
# 4            3.9    883

# %%
fig = px.pie(rating_type_df, names='Dining Rating', values='count', color='count',
title='Percentage of Restaurants by Dining Rating' ).update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in chennai?

# %%
seafood_df = zomato_df[zomato_df['Cuisine'].str.contains('Seafood')]
seafood_df.sort_values(by='Dining Rating',ascending=False).head(10)
# Out:
#                      Name of Restaurant       Location       Cuisine  \
# 595                          The Marina   Nungambakkam    ['Seafood'
# 642   Sera - The Tapas Bar & Restaurant    Gopalapuram    ' Seafood'
# 313                       Urban Spatula    Anna Nagar     ' Seafood'
# 900                             Layalee  Ekkaduthangal    ' Seafood'
# 417                          Azzuri Bay          Adyar    ' Seafood'
# 206                               Samco      Velachery   ' Seafood']
# 700                         The Cascade   Nungambakkam    ['Seafood'
# 46                      Hotel Paramount        Kilpauk    ' Seafood'
# 467                         The Bayleaf    Gopalapuram    ' Seafood'
# 8955                     Copper Kitchen      Velachery   ' Seafood']
#
#                                              Top Dishes  Price for 2  \
# 595   ['Sea Food', ' Jumbo Prawns', ' Biryani', ' Fi...         1600
# ...

# %% [markdown]
# # Q4) Which is the best Food Truck in chennai?

# %%
foodtruck_df = zomato_df[zomato_df['Cuisine'] == 'Food Truck']
foodtruck_df.sort_values(by='Features',ascending=False).head(2)
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine in chennai?

# %%
# Assuming restaurants having rating above 4.5
highest_rated_df = zomato_df[zomato_df['Delivery Rating'] >= 4.5]
highest_rated_df
# Out:
#                        Name of Restaurant         Location            Cuisine  \
# 199    Amadora Gourmet Ice Cream & Sorbet     Nungambakkam        ['Desserts'
# 200    Amadora Gourmet Ice Cream & Sorbet     Nungambakkam      ' Ice Cream']
# 255                 Shri Rajasthani Dhaba      Anna Nagar       ['Rajasthani'
# 256                 Shri Rajasthani Dhaba      Anna Nagar    ' North Indian']
# 302             Fruit Shop On Greams Road  Thousand Lights       ['Beverages'
# ...                                   ...              ...                ...
# 12063                         Kulfi Treat          T.Nagar        ['Desserts'
# 12064                         Kulfi Treat          T.Nagar       ' Ice Cream'
# 12065                         Kulfi Treat          T.Nagar      ' Beverages']
# 12162                       Chennai Kulfi         Kolathur       ['Ice Cream'
# 12163                       Chennai Kulfi         Kolathur       ' Desserts']
#
# ...

# %%
fig = px.histogram(highest_rated_df, x='Location', color='Cuisine',
title= 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine in chennai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#           Cuisine  Dining Rating  Price for 2
# 0     ' Arabian']            3.9        500.0
# 1    ' Beverages'            3.9        300.0
# 2   ' Beverages']            3.6        300.0
# 3   ' Beverages']            3.7        300.0
# 4   ' Beverages']            3.8        100.0

# %%
fig = px.scatter(highest_rated_price_df, x="Cuisine", y="Price for 2", color="Cuisine", symbol="Cuisine",
title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['Cuisine'].str.contains('Chinese')]
chinese_df
# Out:
#                        Name of Restaurant     Location       Cuisine  \
# 8                    SS Hyderabad Biryani  Kodambakkam    ' Chinese'
# 14                          Tasty Kitchen     Perambur    ['Chinese'
# 21                             Dine N Fun   Medavakkam   ' Chinese']
# 25                      Savoury Sea Shell  Anna Nagar     ' Chinese'
# 31               Sangeetha Veg Restaurant      T.Nagar    ' Chinese'
# ...                                   ...          ...           ...
# 12257                         Texas Treat     Selaiyur    ' Chinese'
# 12286                  Anandhi Idly Kadai   Medavakkam   ' Chinese']
# 12288                  Anandhi Idly Kadai     Selaiyur   ' Chinese']
# 12304  Adyar Vaishnavas Thattu Idly Kadai        Porur    ' Chinese'
# 12307                   Engineers Kitchen     Ambattur    ' Chinese'
#
#                                               Top Dishes  Price for 2  \
# ...

# %%
# Assuming your DataFrame is named chinese_df
# Group by 'Location', count restaurants, and calculate average price
chinese_rest_df = chinese_df.groupby(by='Location').agg({'Name of Restaurant' : 'count', 'Price for 2' : 'mean'}).rename(columns={'Name of Restaurant' : 'count'}).reset_index()
#Sort the DataFrame by 'count' column (which is the count of restaurants) in descending order
chinese_rest_df = chinese_rest_df.sort_values('count', ascending=False).head(25)
chinese_rest_df.head(25)
# Out:
#                  Location  count  Price for 2
# 11            Anna Nagar      95   585.789474
# 87                  Porur     58   490.517241
# 6                Ambattur     52   415.384615
# 106               T.Nagar     47   501.063830
# 122             Velachery     46   576.086957
# 83               Perambur     45   476.666667
# 50               Kolathur     45   448.888889
# 90              Ramapuram     43   445.348837
# 60             Medavakkam     42   530.952381
# 116          Thuraipakkam     41   578.048780
# 84              Perungudi     41   507.317073
# 61              Mogappair     41   529.268293
# 108              Tambaram     39   510.256410
# 29               GST Road     36   472.222222
# 2                   Adyar     34   605.882353
# 99               Selaiyur     31   456.451613
# 102        Sholinganallur     30   408.333333
# 45   Kanchipuram District     29   498.275862
# 69           Nungambakkam     29   744.827586
# ...

# %%
fig = px.bar(chinese_rest_df, x='Location', y='count', color='Price for 2',title="No.of Chinese Restaurant by Places") 
fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine?

# %%
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index()
price_rating_df
# Out:
#            Cuisine  Dining Rating  Price for 2
# 0      ' American'            3.2        400.0
# 1      ' American'            3.8       1000.0
# 2      ' American'            3.9        600.0
# 3      ' American'            4.1       1000.0
# 4      ' American'            4.3       1050.0
# ...            ...            ...          ...
# 2091    ['Tibetan'            3.6        400.0
# 2092    ['Tibetan'            3.8        450.0
# 2093    ['Tibetan'            4.1        250.0
# 2094    ['Tibetan'            4.2        350.0
# 2095    ['Turkish'            4.3        500.0
#
# [2096 rows x 3 columns]

# %%
fig = px.line(price_rating_df, y="Price for 2", x="Dining Rating",color='Cuisine')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Cuisine and Price?

# %%
Cuisine_price_df = zomato_df.groupby(['Cuisine'])['Price for 2'].mean().reset_index()
Cuisine_price_df
# Out:
#            Cuisine  Price for 2
# 0      ' American'   950.000000
# 1     ' American']   664.705882
# 2        ' Andhra'   619.444444
# 3       ' Andhra']   411.111111
# 4       ' Arabian'   708.208955
# ..             ...          ...
# 214        ['Tea']   150.000000
# 215        ['Thai'   840.000000
# 216       ['Thai']  1250.000000
# 217     ['Tibetan'   383.333333
# 218     ['Turkish'   500.000000
#
# [219 rows x 2 columns]

# %%
fig = px.scatter(Cuisine_price_df, x="Cuisine", y="Price for 2",title= "Relationship between Cuisine & Price for 2").update_traces(marker_size=8)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?

# %% [markdown]
# # The criteria for Affordable Restaurants would be:-
# # 1) Low Price
# # 2) High Rated
# # First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
# # Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# # restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['Price for 2'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# np.float64(750.0)

# %% [markdown]
# # Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restaurant?

# %%
aff_rest_df = zomato_df[['Name of Restaurant', 'Location','Price for 2', 'Cuisine', 'Top Dishes','Features']]
aff_rest_df = aff_rest_df[aff_rest_df['Price for 2'] <= 1250]
aff_rest_df.sort_values(by='Price for 2', inplace=True)
aff_rest_df
# Out:
#            Name of Restaurant                       Location  Price for 2  \
# 6842  The Sandwich And Shakes                 Sholinganallur          100
# 6841  The Sandwich And Shakes                 Sholinganallur          100
# 6840  The Sandwich And Shakes                 Sholinganallur          100
# 3426           Lassi Junction                    Anna Nagar           100
# 3427           Lassi Junction                    Anna Nagar           100
# ...                       ...                            ...          ...
# 55                     Abid's                        Chetpet         1200
# 56                     Abid's                        Chetpet         1200
# 1288                  Dynasty  Harrisons Hotel, Nungambakkam         1200
# 58                     Abid's                        Chetpet         1200
# 57                     Abid's                        Chetpet         1200
#
#                Cuisine                                         Top Dishes  \
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = zomato_df[['Name of Restaurant', 'Location','Cuisine','Price for 2','Top Dishes','Dining Rating','Delivery Rating','Delivery Rating Count','Features']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['Dining Rating'] >= 4.5]
highrate_rest_df.sort_values(by='Price for 2', inplace=True)
highrate_rest_df
# Out:
#                  Name of Restaurant                        Location  \
# 342                    Rayar's Mess                        Mylapore
# 536             Royal Sandwich Shop                        Alwarpet
# 538             Royal Sandwich Shop                        Alwarpet
# 537             Royal Sandwich Shop                        Alwarpet
# 159                     Andhikkadai                       Velachery
# ..                              ...                             ...
# 692                           Hamsa                           Adyar
# 691                           Hamsa                           Adyar
# 719  Asia Kitchen by Mainland China  The Spring Hotel, Nungambakkam
# 718  Asia Kitchen by Mainland China  The Spring Hotel, Nungambakkam
# 743                       Benjarong                        Alwarpet
#
#               Cuisine  Price for 2  \
# 342  ['South Indian']          100
# 536      ['Fast Food'          150
# 538     ' Beverages']          150
# ...

# %% [markdown]
# # Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['Name of Restaurant', 'Location'])
highrate_aff_df = highrate_aff_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location', 'Top Dishes_x']]
highrate_aff_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'Price for 2_x':'Price for 2', 'Cuisine_x':'Cuisine',
'Location':'Location', 'Top Dishes_x':'Top Dishes'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating
highrate_aff_df
# Out:
#       Name of Restaurant  Price for 2              Cuisine     Location  \
# 0           Rayar's Mess          100     ['South Indian']     Mylapore
# 1    Royal Sandwich Shop          150         ['Fast Food'     Alwarpet
# 2    Royal Sandwich Shop          150         ['Fast Food'     Alwarpet
# 3    Royal Sandwich Shop          150         ['Fast Food'     Alwarpet
# 4    Royal Sandwich Shop          150          ' Desserts'     Alwarpet
# ..                   ...          ...                  ...          ...
# 363             Wok Monk         1200   ' Middle Eastern']  Anna Nagar
# 364             Wok Monk         1200   ' Middle Eastern']  Anna Nagar
# 365             Wok Monk         1200           ' Chinese'  Anna Nagar
# 366             Wok Monk         1200           ' Chinese'  Anna Nagar
# 367             Wok Monk         1200           ' Chinese'  Anna Nagar
#
#                                             Top Dishes
# ...

# %% [markdown]
# # Q11) Find the list of most Reliable Restaurants?
# # The criteria for most Reliable Restaurants would be:-
# # 1) Low Price
# # 2) High Rated
# # 3) Large No. of Votes
# # First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['Dining Rating'].mean()
mean_votes
# Out:
# np.float64(3.4864998781577454)

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location', 'Top Dishes', 'Dining Rating']]
mean_rest_df = mean_rest_df[mean_rest_df['Dining Rating'] >3.4]
mean_rest_df.sort_values(by='Dining Rating', inplace=True)
mean_rest_df
# Out:
#             Name of Restaurant  Price for 2            Cuisine    Location  \
# 3499   Burger & Sandwich Treat          350      ' Beverages']    Mambalam
# 3498   Burger & Sandwich Treat          350       ' Ice Cream'    Mambalam
# 3497   Burger & Sandwich Treat          350       ' Fast Food'    Mambalam
# 12061           Uzo Sandwiches          300       ' Fast Food'  Pallavaram
# 12062           Uzo Sandwiches          300      ' Beverages']  Pallavaram
# ...                        ...          ...                ...         ...
# 553       Gossip Fusion Bistro         1500         ['Italian'    Kanathur
# 560       Gossip Fusion Bistro         1500   ' South Indian']    Kanathur
# 585               Kabab Corner          450           ['Kebab'      Egmore
# 587               Kabab Corner          450        ' Mughlai']      Egmore
# 659      Prems Graama Bhojanam          500   ['South Indian']       Adyar
#
# ...

# %%
# These are the most reliable, highest rated and affordable restaurants:-
# We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# This dataframe obtained below shows the restaurants whose:
# Cost is below = 1250
# Rating is above = 4.5
# Votes (Dining Rating) are above = 3
# Name of Restraunt

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['Name of Restaurant', 'Location'])
reliable_rest_df = reliable_rest_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location', 'Top Dishes_x']]
reliable_rest_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'Price for 2_x':'Price for 2', 'Cuisine_x':'Cuisine',
'Location':'Location', 'Top Dishes_x':'Top Dishes'},inplace=True)

# %%
reliable_rest_df
# Out:
#          Name of Restaurant  Price for 2           Cuisine  Location  \
# 0       Royal Sandwich Shop          150       ' Desserts'  Alwarpet
# 1       Royal Sandwich Shop          150       ' Desserts'  Alwarpet
# 2       Royal Sandwich Shop          150       ' Desserts'  Alwarpet
# 3       Royal Sandwich Shop          150       ' Desserts'  Alwarpet
# 4       Royal Sandwich Shop          150       ' Desserts'  Alwarpet
# ...                     ...          ...               ...       ...
# 1618           Kabab Corner          450       ' Mughlai']    Egmore
# 1619           Kabab Corner          450       ' Mughlai']    Egmore
# 1620           Kabab Corner          450       ' Mughlai']    Egmore
# 1621           Kabab Corner          450       ' Mughlai']    Egmore
# 1622  Prems Graama Bhojanam          500  ['South Indian']     Adyar
#
#                                              Top Dishes
# 0                                               Invalid
# ...
